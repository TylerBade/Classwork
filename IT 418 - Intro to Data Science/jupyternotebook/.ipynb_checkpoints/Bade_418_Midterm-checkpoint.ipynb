# %%
import numpy as np
from numpy.random import randn
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sb

# %%
#exercise 1a
# %matplotlib inline
rcParams['figure.figsize'] = 5,4
sb.set_style('whitegrid')

# %%
x=range(1,10)
y=[1,2,3,4,0,4,3,2,1]

# %%
#exercise 1b
plt.plot(x,y)

# %%
x=[1,2,3,4,0.5]

# %%
#exercise 1c
fig1, ax1 = plt.subplots()
ax1.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x1efe885e3c8>,
# ...
#  [Text(1.05113,0.324231,''),
#   Text(0.401875,1.02396,''),
#   Text(-0.991066,0.477272,''),
#   Text(0.0822033,-1.09692,''),
#   Text(1.08771,-0.163946,'')])

# %%
#exercise 1d
fig1, ax1 = plt.subplots()
labels = 'bicycle','motorbike','car','van','stroller'
ax1.pie(x)
ax1.legend(labels)

# %%
#exercise 1e
fig1.savefig('pie_chart_jpeg')

# %%
from IPython.display import Image
Image('pie_chart_jpeg.png')

# %%
#exercise 2a
mtcars = pd.read_csv('mtcars.csv')
mtcars.head(10)
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# 5            Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# 6         Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# 7          Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# 8           Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# 9           Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2
# 5     1
# 6     4
# 7     2
# 8     2
# 9     4

# %%
#exercise 2b
mtcars.plot(y='mpg')

# %%
#exercise 2c
fig, ax = plt.subplots()
plt.plot(mtcars['mpg'], label='mpg')
plt.plot(mtcars['wt'], label='wt')
plt.plot(mtcars['cyl'], label='cyl')
leg=ax.legend();

# %%
#exercise 2d
fig, ax = plt.subplots()
plt.plot(mtcars['mpg'], color='orange', label='mpg')
plt.plot(mtcars['wt'], color='brown', label='wt')
plt.plot(mtcars['cyl'], color='red', label='cyl')
leg=ax.legend();

# %%
#exercise 2e
plt.bar(np.arange(len(mtcars)), mtcars['mpg'], align='center', alpha=0.5)
# Out:
# <Container object of 32 artists>

# %%
#exercise 2f
plt.barh(np.arange(len(mtcars)), mtcars['mpg'], align='center', alpha=0.5)
# Out:
# <Container object of 32 artists>

# %%
#exercise 2g
max(mtcars['mpg'])
# Out:
# 33.899999999999999

# %%
#exercise 2h
plt.hist(mtcars['mpg'])
# Out:
# (array([ 2.,  4.,  6.,  6.,  5.,  3.,  1.,  1.,  2.,  2.]),
#  array([ 10.4 ,  12.75,  15.1 ,  17.45,  19.8 ,  22.15,  24.5 ,  26.85,
#          29.2 ,  31.55,  33.9 ]),
#  <a list of 10 Patch objects>)

# %%
#exercise 2i
sb.distplot(mtcars['mpg'])

# %%
#exercise 2j
plt.scatter(x=mtcars['hp'], y=mtcars['mpg'])

# %%
#exercise 2k
sb.regplot('hp', 'mpg', data=mtcars)

# %%
#exercise 2l
pp = sb.pairplot(mtcars, vars=['mpg','cyl','disp','hp','drat','wt','qsec','vs','am'])
pp.map(plt.scatter)

# %%
#exercise 2m
mtcars.boxplot(column='mpg', by='am')
# Out:
# D:\Anaconda\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
#exercise 2n
ax = sb.boxplot(x='am', y='mpg', data=mtcars, palette='hls')
ax.set_title('Boxplot grouped by am')
# Out:
# Text(0.5,1,'Boxplot grouped by am')

# %%
#exercise 2o
#1) am values of 1 tend to have higher mpg values
#2) as hp goes up, mpg tends to go down
#3) all cars chart between 10 and 35 mpg
#4) the largest distribution of mpg is between 15 and 25 mpg
#5) lower wt and cyl variables tend to coincide with higher mpg
